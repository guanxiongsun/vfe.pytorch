# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
marker = 'o--'
label = 'R-50/ 101'
x = [43.5, 51.3]
y = [44.3, 48.5]
l1=plt.plot(x, y, marker, label=label, markersize=10)
marker = 's--'
label = 'Swin-T/ S/ B'
x = [43.9, 59.9, 78.1]
y = [47.1, 52.6, 53.2]
l2=plt.plot(x, y, marker, label=label, markersize=10)
marker = '^--'
label = 'TDViT- T  / S   / B \nTDViT-T$^+$/ S$^+$/ B$^+$'
x = [43.5, 45.6, 59.5, 61.8, 77.6, 81.7]
y = [49.1, 50.9, 55.4, 55.7, 56.0, 56.1]
l3=plt.plot(x, y, marker, label=label, markersize=10)


plt.xlabel('runtime (ms)', fontsize=15)
plt.ylabel(r'accuracy (AP$_{50}$)', fontsize=15)

# plt.xlim(35, 85)
# plt.ylim(72, 88)
plt.legend(shadow=True, fontsize=15)
# plt.legend().get_frame().set_facecolor('C0')
#plt.savefig('foo.png')
plt.gca().set_aspect(aspect=2.5)
for item in plt.gca().get_xticklabels():
    item.set_fontsize(15)
for item in plt.gca().get_yticklabels():
    item.set_fontsize(15)
plt.savefig('foo.pdf')
